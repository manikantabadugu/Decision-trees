# %%
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.decomposition import PCA
import pandas as pd

# %%
def load_data():
    x=datasets.load_iris()
    return  x

# %%
dataset = load_data()
load_data().feature_names
#dataset.keys()
df = pd.DataFrame(dataset["data"], columns=dataset.feature_names)
df.columns=["sepal length", "sepal width", "petal length", "petal width"]
df['target']=dataset.target
target_names=dataset.target_names
df['class']=df['target'].replace({0:target_names[0],1:target_names[1],2:target_names[2]})
df
# Out:
#      sepal length  sepal width  petal length  petal width  target      class
# 0             5.1          3.5           1.4          0.2       0     setosa
# 1             4.9          3.0           1.4          0.2       0     setosa
# 2             4.7          3.2           1.3          0.2       0     setosa
# 3             4.6          3.1           1.5          0.2       0     setosa
# 4             5.0          3.6           1.4          0.2       0     setosa
# ..            ...          ...           ...          ...     ...        ...
# 145           6.7          3.0           5.2          2.3       2  virginica
# 146           6.3          2.5           5.0          1.9       2  virginica
# 147           6.5          3.0           5.2          2.0       2  virginica
# 148           6.2          3.4           5.4          2.3       2  virginica
# 149           5.9          3.0           5.1          1.8       2  virginica
#
# [150 rows x 6 columns]

# %%
df = df.drop(["class"], axis=1)
df
# Out:
#      sepal length  sepal width  petal length  petal width  target
# 0             5.1          3.5           1.4          0.2       0
# 1             4.9          3.0           1.4          0.2       0
# 2             4.7          3.2           1.3          0.2       0
# 3             4.6          3.1           1.5          0.2       0
# 4             5.0          3.6           1.4          0.2       0
# ..            ...          ...           ...          ...     ...
# 145           6.7          3.0           5.2          2.3       2
# 146           6.3          2.5           5.0          1.9       2
# 147           6.5          3.0           5.2          2.0       2
# 148           6.2          3.4           5.4          2.3       2
# 149           5.9          3.0           5.1          1.8       2
#
# [150 rows x 5 columns]

# %%
X, y = df.iloc[:, :-1], df.iloc[:, -1]

# %%
import matplotlib.pyplot as plt
for col_name in df.columns:
        plt.figure()
        plt.hist(df[col_name])
        plt.title(col_name)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.3)

# %%
dt_clf = DecisionTreeClassifier(random_state=42)
dt_clf = dt_clf.fit(X_train, y_train)

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(15, 15))
plot_tree(dt_clf,
          filled=True,
          rounded=True,
          class_names=['setosa', 'versicolor', 'virginica'],
         feature_names=X.columns)
# Out:
# [Text(257.53846153846155, 757.1571428571428, 'petal length <= 2.45\ngini = 0.664\nsamples = 105\nvalue = [31, 37, 37]\nclass = versicolor'),
#  Text(193.15384615384616, 640.6714285714286, 'gini = 0.0\nsamples = 31\nvalue = [31, 0, 0]\nclass = setosa'),
#  Text(321.9230769230769, 640.6714285714286, 'petal length <= 4.75\ngini = 0.5\nsamples = 74\nvalue = [0, 37, 37]\nclass = versicolor'),
#  Text(128.76923076923077, 524.1857142857143, 'petal width <= 1.6\ngini = 0.059\nsamples = 33\nvalue = [0, 32, 1]\nclass = versicolor'),
#  Text(64.38461538461539, 407.7, 'gini = 0.0\nsamples = 32\nvalue = [0, 32, 0]\nclass = versicolor'),
#  Text(193.15384615384616, 407.7, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = virginica'),
#  Text(515.0769230769231, 524.1857142857143, 'petal width <= 1.75\ngini = 0.214\nsamples = 41\nvalue = [0, 5, 36]\nclass = virginica'),
#  Text(321.9230769230769, 407.7, 'petal length <= 4.95\ngini = 0.5\nsamples = 8\nvalue = [0, 4, 4]\nclass = versicolor'),
#  Text(257.53846153846155, 291.21428571428567, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]\nclass = versicolor'),
#  Text(386.3076923076923, 291.21428571428567, 'petal width <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]\nclass = virginica'),
#  Text(321.9230769230769, 174.7285714285714, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]\nclass = virginica'),
#  Text(450.69230769230774, 174.7285714285714, 'petal length <= 5.45\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]\nclass = versicolor'),
#  Text(386.3076923076923, 58.24285714285713, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]\nclass = versicolor'),
#  Text(515.0769230769231, 58.24285714285713, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = virginica'),
#  Text(708.2307692307693, 407.7, 'petal length <= 4.85\ngini = 0.059\nsamples = 33\nvalue = [0, 1, 32]\nclass = virginica'),
#  Text(643.8461538461538, 291.21428571428567, 'sepal width <= 3.1\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]\nclass = virginica'),
#  Text(579.4615384615385, 174.7285714285714, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]\nclass = virginica'),
#  Text(708.2307692307693, 174.7285714285714, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = versicolor'),
#  Text(772.6153846153846, 291.21428571428567, 'gini = 0.0\nsamples = 30\nvalue = [0, 0, 30]\nclass = virginica')]

# %%
from sklearn.metrics import plot_confusion_matrix

plot_confusion_matrix(dt_clf, X_test, y_test, display_labels=['setosa', 'versicolor', 'virginica'])
